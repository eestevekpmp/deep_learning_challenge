# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from keras import losses
from keras import optimizers
from keras import metrics

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
# Optimization method of reducing additional non-benificial ID columns
clean_application_df = application_df.drop(columns=['EIN','NAME','STATUS','AFFILIATION'])
clean_application_df.head()
# Out:
#   APPLICATION_TYPE CLASSIFICATION      USE_CASE  ORGANIZATION     INCOME_AMT  \
# 0              T10          C1000    ProductDev   Association              0
# 1               T3          C2000  Preservation  Co-operative         1-9999
# 2               T5          C3000    ProductDev   Association              0
# 3               T3          C2000  Preservation         Trust    10000-24999
# 4               T3          C1000     Heathcare         Trust  100000-499999
#
#   SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0                      N     5000              1
# 1                      N   108590              1
# 2                      N     5000              0
# 3                      N     6692              1
# 4                      N   142590              1

# %%
# Determine the number of unique values in each column.
unique_values_col = clean_application_df.nunique(axis=0)
unique_values_col
# Out:
# APPLICATION_TYPE            17
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
clean_application_type_counts = clean_application_df['APPLICATION_TYPE'].value_counts()
clean_application_type_counts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(clean_application_type_counts[clean_application_type_counts < 500].index)

# Replace in dataframe
for app in application_types_to_replace:
    clean_application_df['APPLICATION_TYPE'] = clean_application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
clean_application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
clean_classification_counts = clean_application_df['CLASSIFICATION'].value_counts()
clean_classification_counts
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
clean_classfication_counts_above_one = clean_classification_counts[clean_classification_counts > 1]
clean_classfication_counts_above_one
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(clean_classification_counts[clean_classification_counts < 1800].index)


# Replace in dataframe
for cls in classifications_to_replace:
    clean_application_df['CLASSIFICATION'] = clean_application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
clean_application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`

clean_application_df = pd.get_dummies(clean_application_df)
clean_application_df.head()
# Out:
#    ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  APPLICATION_TYPE_T10  \
# 0     5000              1                       0                     1
# 1   108590              1                       0                     0
# 2     5000              0                       0                     0
# 3     6692              1                       0                     0
# 4   142590              1                       0                     0
#
#    APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  \
# 0                     0                    0                    0
# 1                     0                    1                    0
# 2                     0                    0                    0
# 3                     0                    1                    0
# 4                     0                    1                    0
#
#    APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  APPLICATION_TYPE_T7  ...  \
# ...

# %%
# Split our preprocessed data into our features and target arrays
y = clean_application_df["IS_SUCCESSFUL"].values
X = clean_application_df.drop(["IS_SUCCESSFUL"],1).values

# Split the preprocessed data into a training and testing dataset
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=78)
# Out:
# <ipython-input-47-fd4f22170027>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X = clean_application_df.drop(["IS_SUCCESSFUL"],1).values

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
#number_input_features
hidden_nodes_layer1 = 40
hidden_nodes_layer2 = 30
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features,activation="relu")
)

# Second hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer2,activation="relu")
)

# Output layer
nn.add(tf.keras.layers.Dense(units=1,activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 40)                1480
#
#  dense_7 (Dense)             (None, 30)                1230
#
#  dense_8 (Dense)             (None, 1)                 31
#
# ...
# Total params: 2,741
# Trainable params: 2,741
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics="accuracy")

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=11)
# Out:
# Epoch 1/11
# 804/804 [==============================] - 3s 2ms/step - loss: 0.6253 - accuracy: 0.6419
# Epoch 2/11
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6141 - accuracy: 0.6508
# Epoch 3/11
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6119 - accuracy: 0.6528
# Epoch 4/11
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6112 - accuracy: 0.6538
# Epoch 5/11
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6098 - accuracy: 0.6541
# Epoch 6/11
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6086 - accuracy: 0.6539
# Epoch 7/11
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6084 - accuracy: 0.6558
# Epoch 8/11
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6084 - accuracy: 0.6538
# Epoch 9/11
# 804/804 [==============================] - 3s 4ms/step - loss: 0.6077 - accuracy: 0.6539
# Epoch 10/11
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.6070 - accuracy: 0.6608 - 471ms/epoch - 2ms/step
# Loss: 0.6069716811180115, Accuracy: 0.6607580184936523

# %%
# Export our model to HDF5 file
nn.save("AlphabetSoupCharityOptimization Method 2.h5")
